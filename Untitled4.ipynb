# %% [markdown]
# <a href="https://colab.research.google.com/github/Riskiejdjd/world-poverty/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

# !pip install pandas
import pandas as pd

# !pip install numpy
import numpy as np

# !pip install seaborn
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
